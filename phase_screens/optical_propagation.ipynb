# %% [markdown]
# Scintillation Patterns
# ----------------------

# %%
import numpy
import matplotlib.pylab as plt
from tqdm import tqdm, trange, tqdm_notebook
from astropy.io import fits

import aotools
from aotools.turbulence import ft_phase_screen
j = 0+1j

# %%
# Set up parameters for creating phase screens
nx_size = 1024
D = 4.
pxl_scale = D/nx_size
r0 = 0.164
L0 = 100
l0=0.001
wind_speed = 10 #m/s - just arbitrarily set

# %%
phase_screen = ft_phase_screen(r0, nx_size, pxl_scale, L0, l0)
print(phase_screen.shape)
plt.figure()
plt.imshow(phase_screen)
cbar = plt.colorbar()
cbar.set_label('Wavefront deviation (nm)', labelpad=8)
# Out:
# (1024, 1024)

# %%
propagated_screen = aotools.opticalpropagation.angularSpectrum(numpy.exp(j*phase_screen), 500e-9, pxl_scale, pxl_scale, 10000.)
plt.figure()
plt.imshow(numpy.abs(propagated_screen)**2.)
plt.colorbar()
